# %%
print("hi")
# Out:
# hi

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data =  pd.read_csv('raw_data/artDataset.csv')

# %%
data
# Out:
#      Unnamed: 0       price                    artist                  title  \
# 0             0  28.500 USD           Tommaso Ottieri         Bayreuth Opera
# 1             1   3.000 USD         Pavel Tchelitchew  Drawings of the Opera
# 2             2   5.000 USD                 Leo Gabin        Two on Sidewalk
# 3             3   5.000 USD         Matthias Dornfeld            Blumenszene
# 4             4   2.500 USD  Alexis Marguerite Teplin   Feverish Embarkation
# ..          ...         ...                       ...                    ...
# 749         749     680 USD                 Jane Kent       Miracle Grow #17
# 750         750   1.275 USD                Gary Bower           Rolph Series
# 751         751     680 USD                 Jane Kent               Untitled
# 752         752   1.275 USD              T. L. Solien                Juniper
# 753         753     680 USD                 John Duff         Untitled Print
#
#                  yearCreation  \
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.groupby('artist')["artist"].nunique()
# Out:
# artist
# Aaron Siskind          1
# Abelardo Morell        1
# Adolf Schreyer         1
# Adrian Wiszniewski     1
# Adrianne Wortzel       1
#                       ..
# Yinka Shonibare CBE    1
# Yong Jo Ji             1
# Yvonne Jacquette       1
# Zak Smith              1
# Zhang Yu               1
# Name: artist, Length: 454, dtype: int64

# %%
data["artist"].value_counts()
# Out:
# artist
# Russell Young        17
# John Fischer         15
# Ruth Bernhard        13
# Donald Sultan         9
# Richard Bernstein     8
#                      ..
# Enoc Perez            1
# Jutta Koether         1
# Ludwig Bemelmans      1
# Lisa Oppenheim        1
# Julia Rommel          1
# Name: count, Length: 454, dtype: int64

# %%
data["price"].value_counts()
# Out:
# price
# 800 USD       124
# 1.500 USD      94
# 680 USD        46
# 3.000 USD      43
# 1.275 USD      43
#              ...
# 8.750 USD       1
# 71.500 USD      1
# 2.600 USD       1
# 1.875 USD       1
# 2.160 USD       1
# Name: count, Length: 108, dtype: int64

# %%
list_price = data["price"].value_counts()
filtered_price = data[data["price"].map(data["price"].value_counts())>5]
filtered_price
# Out:
#      Unnamed: 0       price                    artist                  title  \
# 1             1   3.000 USD         Pavel Tchelitchew  Drawings of the Opera
# 2             2   5.000 USD                 Leo Gabin        Two on Sidewalk
# 3             3   5.000 USD         Matthias Dornfeld            Blumenszene
# 4             4   2.500 USD  Alexis Marguerite Teplin   Feverish Embarkation
# 12           12  15.000 USD                  Zhang Yu                 96.6.2
# ..          ...         ...                       ...                    ...
# 749         749     680 USD                 Jane Kent       Miracle Grow #17
# 750         750   1.275 USD                Gary Bower           Rolph Series
# 751         751     680 USD                 Jane Kent               Untitled
# 752         752   1.275 USD              T. L. Solien                Juniper
# 753         753     680 USD                 John Duff         Untitled Print
#
#                  yearCreation  \
# ...

# %%
fig, axs = plt.subplots(2, 1, figsize=(20, 5))

# We can set the number of bins with the *bins* keyword argument.
axs[0].hist(filtered_price["price"],bins=50)
axs[1].hist(data['yearCreation'],bins=50)

plt.show()

# %%
plt.figure(figsize=(20, 5))
plt.hist(filtered_price["price"],bins=50)
plt.show()

# %%
plt.figure(figsize=(20, 5))
plt.hist(data["price"])
plt.show()

# %%
# Convert price strings into integers
data['price'] = data['price'].str.replace('USD', '')
data['price'] = data['price'].str.replace('.', '')
data['price'] = data['price'].astype(int)

# %%
# Convert strings of yearCreation into integers

# Remove 'circa'
data['yearCreation'] = data['yearCreation'].str.replace('circa', '')
# Remove 'Circa'
data['yearCreation'] = data['yearCreation'].str.replace('Circa', '')
# Strip empty spaces
data['yearCreation'] = data['yearCreation'].str.strip()

# %%
clock = data[data['yearCreation'] == '3D printed using ABS, PLA plastics, resin, automobile paints, etched brass, dry transfers, acrylic mirror, batik fabric, quartz clock'].index
clock
# Out:
# Index([90], dtype='int64')

# %%
data.loc[112]
# Out:
# Unnamed: 0                                                    112
# price                                                        6000
# artist                                              Russell Young
# title                                        Marilyn Crying (B+W)
# yearCreation                                                [nan]
# signed                              Signed by artist bottom right
# condition       This work is in excellent condition.There is s...
# period                                               Contemporary
# movement                                                  Pop Art
# Name: 112, dtype: object

# %%
data = data.drop(90)

# %%
data
# Out:
#      Unnamed: 0  price                    artist                  title  \
# 0             0  28500           Tommaso Ottieri         Bayreuth Opera
# 1             1   3000         Pavel Tchelitchew  Drawings of the Opera
# 2             2   5000                 Leo Gabin        Two on Sidewalk
# 3             3   5000         Matthias Dornfeld            Blumenszene
# 4             4   2500  Alexis Marguerite Teplin   Feverish Embarkation
# ..          ...    ...                       ...                    ...
# 749         749    680                 Jane Kent       Miracle Grow #17
# 750         750   1275                Gary Bower           Rolph Series
# 751         751    680                 Jane Kent               Untitled
# 752         752   1275              T. L. Solien                Juniper
# 753         753    680                 John Duff         Untitled Print
#
#                 yearCreation  \
# 0                       2021
# 1    First Half 20th Century
# ...

# %%
data["condition"].value_counts()
# Out:
# condition
# Excellent condition.                                                                                                                                                                                                                                                                                                                                                                                                                 82
# The work is in excellent condition, direct from the publisher.                                                                                                                                                                                                                                                                                                                                                                       50
# ...

# %%
data[data['title'].str.contains('marble|bronze|terracotta|sculpt|ceramic|3D|wood|vessel')]
# Out:
#      Unnamed: 0  price         artist                        title  \
# 16           16   5000   Anne Appleby                   Cottonwood
# 225         225   9000     Ed  Ruscha  Petro Plots: Hollywood/Vine
# 435         435   2000  Ruth Bernhard          Shell and Driftwood
#
#     yearCreation                                       signed  \
# 16          2012                           Signed lower right
# 225         2001                                        [nan]
# 435         1943  Signed and titled in pencil on the reverse.
#
#                                              condition        period  \
# 16   This work is in excellent condition, direct fr...  Contemporary
# 225  The work is in excellent condition, direct fro...  Contemporary
# 435  This print is in generally excellent condition...        Modern
#
#         movement
# 16    Minimalism
# 225  Conceptual
# 435      Realism

# %%
data[data['title'].str.contains('marble|Juniper|umensz')]
# Out:
#      Unnamed: 0  price             artist        title yearCreation  \
# 3             3   5000  Matthias Dornfeld  Blumenszene         2010
# 752         752   1275       T. L. Solien      Juniper         1986
#
#                                                 signed  \
# 3    Signed, titled and dated on the reverse with t...
# 752                                              [nan]
#
#                                              condition        period  movement
# 3    This work is in excellent condition.There is m...  Contemporary  Abstract
# 752  Not examined outside of frame.Pinholes at edge...  Contemporary  Abstract
